# %% [markdown]
# <br> Student Name: Tenicka Norwood
# <br> MSDS 550
# <br>📌 Meharry Medical College
# <br> Related Paper (URL): https://www.semanticscholar.org/paper/Nuclear-feature-extraction-for-breast-tumor-Street-Wolberg/53f0fbb425bc14468eb3bf96b2e1d41ba8087f36

# %% [markdown]
# ## 📌 Disclaimer:
#
# This Jupyter notebook and its contents are intended solely for educational purposes. The analysis and results presented should not be interpreted as medical advice. This model has not been reviewed or endorsed by any professional medical organization.
#
# The findings are for illustrative purposes only, and users should not rely on these predictions for clinical decision-making. Consult a licensed medical professional for diagnosis and treatment. The dataset used may not fully represent real-world clinical scenarios, and predictions should be interpreted with caution.
#
# The author and contributors of this notebook disclaim any liability for the accuracy, completeness, or efficacy of the information provided.
#
# ## 📌 Overview:
#
# The primary objective of this project is to develop a linear regression model capable of predicting tumor area (Area Mean) based on various diagnostic features.
#
# Leveraging machine learning, Zenith Medical Analytics aims to explore how different cellular characteristics influence tumor size, which could contribute to better understanding of tumor growth patterns and potential risk factors.
#
# ## 📌 Objectives and Goals:
#
# The goal of this project is to explore various statistical and machine learning techniques to develop a precise and reliable model that predicts tumor area using diagnostic measurements.
#
# By analyzing key relationships between cellular features and tumor size, we aim to:✅ Identify the strongest predictors of tumor area.✅ Understand feature interactions that impact tumor size.✅ Assess model accuracy using evaluation metrics such as R-squared, Mean Squared Error (MSE), and Mean Absolute Error (MAE).
#
# ## 📌 Problem Statement:
#
# Accurately estimating tumor size is crucial for treatment planning and prognosis. Zenith Medical Analytics seeks to leverage machine learning to develop a predictive model for tumor area, enabling deeper insights into how diagnostic features correlate with tumor growth.
#
# This model will provide a quantitative approach to estimating tumor size based on features extracted from biopsy images, potentially aiding in research and exploratory data analysis for breast cancer diagnosis.
#
# ## 📌 Stakeholder:
#
# Zenith Medical Analytics
#
# Oncologists & Medical Researchers
#
# Breast Cancer Research & Diagnostic Centers
#
# ## 📌 Business Case:
#
# As the newly appointed lead of the data analytics team at Zenith Medical Analytics, my team has been tasked with analyzing the relationship between cellular features and tumor area using advanced predictive modeling techniques.
#
# The successful implementation of this model will:
#
# ✅ Provide insights into which cellular features strongly influence tumor size.<br>✅ Support medical research in identifying potential patterns in tumor growth.<br>✅ Assess the reliability of a linear regression approach for tumor size prediction.<br>✅ Help refine future models aimed at tumor characterization.
#
# ## 📌 Success Criteria:
#
# The project will be evaluated based on its ability to generate accurate and interpretable predictions for tumor areas.
#
# Key performance metrics:
#
# <br>✅ Mean Squared Error (MSE): Measures the average squared difference between actual and predicted tumor area.<br>✅ Mean Absolute Error (MAE): Provides an average of absolute differences, and gives a clear measure of model performance.<br>✅ R-squared (R²): Indicates how well the independent variables explain the variance in tumor area.
#
# The model's success will be measured by achieving an R² score above 0.75, which indicates the selected features' strong explanatory power in predicting tumor area.
#
# Mathematical Representation of Model Evaluation:
# $$
# MSE = \frac{1}{n} \sum_{i=1}^{n} (y_i - \hat{y}_i)^2
# $$
#
# $$
# MAE = \frac{1}{n} \sum_{i=1}^{n} |y_i - \hat{y}_i|
# $$
#
# $$
# R^2 = 1 - \frac{SS_{res}}{SS_{tot}}
# $$
# where:
#  $$
#  y_i = \text{actual tumor area}
#  $$
#
# $$
# \hat{y}_i = \text{predicted tumor area }
# $$
#
# $$
#  SS_{res}= \text{sum of squared residuals}
# $$
#
# $$
#  SS_{tot} = \text{total sum of squares}
# $$
# This project aligns with **Zenith Medical Analytics'** mission to drive data-driven insights in breast cancer research, ensuring more accurate and reliable tumor characterization.

# %% [markdown]
# # 📌 Task 1: Dataset Selection
# The **Breast Cancer Wisconsin (Diagnostic) dataset** is a collection of features extracted from digitized images of fine needle aspirate (FNA) samples of breast masses. These features help in distinguishing between **benign (non-cancerous) and malignant (cancerous) tumors**.
#
# __Features__ : 30 numerical features
# <br> __Observations__: 569
#
# | **Feature**              | **Data Type**   | **Description**                                                 | **Type**        | **Unit**       |
# |--------------------------|----------------|-----------------------------------------------------------------|-----------------|---------------|
# | `ID`                     | Numeric        | Unique identification number for each patient                   | Identifier      | N/A           |
# | `Diagnosis`              | Categorical    | Diagnosis of the tumor (`M` = Malignant, `B` = Benign)          | Binary          | N/A           |
# | `Radius_mean`            | Numeric        | Mean of distances from center to points on the perimeter        | Continuous      | mm            |
# | `Texture_mean`           | Numeric        | Standard deviation of gray-scale values                         | Continuous      | Unitless      |
# | `Perimeter_mean`         | Numeric        | Mean size of the core tumor perimeter                           | Continuous      | mm            |
# | `Area_mean`              | Numeric        | Mean size of the core tumor area                                | Target Variable | mm²           |
# | `Smoothness_mean`        | Numeric        | Local variation in radius lengths                               | Continuous      | Unitless      |
# | `Compactness_mean`       | Numeric        | Compactness = (perimeter² / area - 1.0)                         | Continuous      | Unitless      |
# | `Concavity_mean`         | Numeric        | Severity of concave portions of the contour                     | Continuous      | Unitless      |
# | `Concave_points_mean`    | Numeric        | Number of concave portions of the contour                       | Continuous      | Unitless      |
# | `Symmetry_mean`          | Numeric        | Symmetry of the cell nuclei                                     | Continuous      | Unitless      |
# | `Fractal_dimension_mean` | Numeric        | "Coastline approximation" of the cell's shape complexity        | Continuous      | Unitless      |
# | `Radius_se`             | Numeric        | Standard error for `Radius_mean`                                | Continuous      | mm            |
# | `Texture_se`            | Numeric        | Standard error for `Texture_mean`                               | Continuous      | Unitless      |
# | `Perimeter_se`          | Numeric        | Standard error for `Perimeter_mean`                             | Continuous      | mm            |
# | `Area_se`               | Numeric        | Standard error for `Area_mean`                                  | Continuous      | mm²           |
# | `Smoothness_se`         | Numeric        | Standard error for `Smoothness_mean`                            | Continuous      | Unitless      |
# | `Compactness_se`        | Numeric        | Standard error for `Compactness_mean`                           | Continuous      | Unitless      |
# | `Concavity_se`          | Numeric        | Standard error for `Concavity_mean`                             | Continuous      | Unitless      |
# | `Concave_points_se`     | Numeric        | Standard error for `Concave_points_mean`                        | Continuous      | Unitless      |
# | `Symmetry_se`           | Numeric        | Standard error for `Symmetry_mean`                              | Continuous      | Unitless      |
# | `Fractal_dimension_se`  | Numeric        | Standard error for `Fractal_dimension_mean`                     | Continuous      | Unitless      |
# | `Radius_worst`          | Numeric        | Worst (largest) mean radius observed                            | Continuous      | mm            |
# | `Texture_worst`         | Numeric        | Worst (largest) mean texture observed                           | Continuous      | Unitless      |
# | `Perimeter_worst`       | Numeric        | Worst (largest) mean perimeter observed                         | Continuous      | mm            |
# | `Area_worst`            | Numeric        | Worst (largest) mean area observed                              | Continuous      | mm²           |
# | `Smoothness_worst`      | Numeric        | Worst (largest) mean smoothness observed                        | Continuous      | Unitless      |
# | `Compactness_worst`     | Numeric        | Worst (largest) mean compactness observed                       | Continuous      | Unitless      |
# | `Concavity_worst`       | Numeric        | Worst (largest) mean concavity observed                         | Continuous      | Unitless      |
# | `Concave_points_worst`  | Numeric        | Worst (largest) mean concave points observed                    | Continuous      | Unitless      |
# | `Symmetry_worst`        | Numeric        | Worst (largest) mean symmetry observed                          | Continuous      | Unitless      |
# | `Fractal_dimension_worst` | Numeric      | Worst (largest) mean fractal dimension observed                 | Continuous      | Unitless      |
#
# ---
#
# ## 📌 Data Source
# The dataset was compiled by **Dr. William H. Wolberg** from the University of Wisconsin Hospitals.
# It is available on the [UCI Machine Learning Repository](https://archive.ics.uci.edu/dataset/17/breast+cancer+wisconsin+diagnostic).
#
# ### **Sources:**
# - W. H. Wolberg, W. N. Street, and O. L. Mangasarian (1995). *Breast Cancer Wisconsin (Diagnostic) Dataset.*
#   DOI: [10.24432/C52P4X](https://archive.ics.uci.edu/ml/datasets/Breast+Cancer+Wisconsin+(Diagnostic)).
#
# ---
#
# ## 📌 Data Preprocessing & Analysis Plan
# To fully analyze this dataset, we will:
# 1. **Load and Inspect the Data**
#    - Check for missing values and overall structure.
# 2. **Preprocess the Data**
#    - Convert categorical variables (`Diagnosis`) into numerical format.
#    - Handle missing or incomplete data entries.
#    - Standardize numerical features.
# 3. **Explore Data Features**
#    - Perform feature correlation analysis.
#    - Visualize distributions and relationships between features.
# 4. **Apply Machine Learning Models**
#    - Compare various models (**Logistic Regression, SVM, Random Forest, Decision Tree, KNN**) for tumor classification.
# 5. **Evaluate Model Performance**
#    - Use metrics like **accuracy, precision, recall, F1-score, confusion matrix, and ROC-AUC**.
# 6. **Deploy Model for Predictions**
#    - Build a simple function to classify new breast cancer cases.

# %%
# import libraries and packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
# Load and Inspect the Data
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/breast-cancer-wisconsin/wdbc.data"
columns = ['ID', 'Diagnosis', 'Radius Mean', 'Texture Mean', 'Perimeter Mean', 'Area Mean', 'Smoothness Mean',
           'Compactness Mean', 'Concavity Mean', 'Concave Points Mean', 'Symmetry Mean', 'Fractal Dimension Mean',
           'Radius SE', 'Texture SE', 'Perimeter SE', 'Area SE', 'Smoothness SE', 'Compactness SE',
           'Concavity SE', 'Concave Points SE', 'Symmetry SE', 'Fractal Dimension SE',
           'Radius Worst', 'Texture Worst', 'Perimeter Worst', 'Area Worst', 'Smoothness Worst',
           'Compactness Worst', 'Concavity Worst', 'Concave Points Worst', 'Symmetry Worst', 'Fractal Dimension Worst']

data = pd.read_csv(url, header=None, names=columns)

# %%
data.head()
# Out:
#          ID Diagnosis  Radius Mean  Texture Mean  Perimeter Mean  Area Mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    Smoothness Mean  Compactness Mean  Concavity Mean  Concave Points Mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
data.describe()
# Out:
#                  ID  Radius Mean  Texture Mean  Perimeter Mean    Area Mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        Smoothness Mean  Compactness Mean  Concavity Mean  Concave Points Mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       569 non-null    int64
#  1   Diagnosis                569 non-null    object
#  2   Radius Mean              569 non-null    float64
#  3   Texture Mean             569 non-null    float64
#  4   Perimeter Mean           569 non-null    float64
#  5   Area Mean                569 non-null    float64
#  6   Smoothness Mean          569 non-null    float64
#  7   Compactness Mean         569 non-null    float64
#  8   Concavity Mean           569 non-null    float64
#  9   Concave Points Mean      569 non-null    float64
#  10  Symmetry Mean            569 non-null    float64
#  11  Fractal Dimension Mean   569 non-null    float64
#  12  Radius SE                569 non-null    float64
#  13  Texture SE               569 non-null    float64
# ...

# %% [markdown]
# Based on inspection, we notice that there are no missing variables.

# %%
# Preprocess the Data
# Drop ID column (not needed for modeling)
data.drop(columns=['ID'], inplace=True)

# Convert Diagnosis to binary (Malignant=1, Benign=0)
data['Diagnosis'] = data['Diagnosis'].map({'M': 1, 'B': 0})

# %% [markdown]
# # 📌 Task 2: Data Visualization

# %%
# Data visualization
plt.figure(figsize=(12, 6))
sns.histplot(data['Area Mean'], bins=30, kde=True)
plt.title("Histogram of Area Mean")
plt.show()

# %%
# Create Heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(data.corr(), annot=False, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
# Create Scatter plot
sns.scatterplot(x=data['Radius Mean'], y=data['Area Mean'])
plt.title("Scatter Plot: Radius Mean vs Area Mean")
plt.show()

# %%
# Create Box Plot
sns.boxplot(x=data['Diagnosis'], y=data['Area Mean'])
plt.title("Box Plot of Area Mean by Diagnosis")
plt.show()

# %%
# Create Pairplot
sns.pairplot(data, vars=['Radius Mean', 'Texture Mean', 'Perimeter Mean', 'Area Mean'])
plt.show()

# %% [markdown]
# # 📌 Task 3: Define Variables

# %%
# Define target and predictors
target = 'Area Mean'
predictors = [col for col in data.columns if col not in ['Area Mean', 'Diagnosis']]

# %%
# Split dataset
X_train, X_test, y_train, y_test = train_test_split(data[predictors], data[target], test_size=0.2, random_state=42)

# Train linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Predictions
y_pred = model.predict(X_test)

# Model evaluation
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"Mean Absolute Error: {mae}")
print(f"R-squared: {r2}")
# Out:
# Mean Squared Error: 480.05343816048946
# Mean Absolute Error: 13.8884650032078
# R-squared: 0.9958368973315227

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Compute correlation matrix
correlation_matrix = data.corr()

# Get the features most correlated with 'Area Mean'
correlated_features = correlation_matrix['Area Mean'].abs().sort_values(ascending=False).index[1:6]  # Excluding 'Area Mean' itself

# Generate box plots for the most correlated features
plt.figure(figsize=(15, 8))
for i, feature in enumerate(correlated_features, 1):
    plt.subplot(2, 3, i)
    sns.boxplot(x=data['Diagnosis'], y=data[feature])
    plt.title(f"Box Plot of {feature} by Diagnosis")

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Compute correlation matrix
correlation_matrix = data.corr()

# Get the features most correlated with 'Area Mean'
correlated_features = correlation_matrix['Area Mean'].abs().sort_values(ascending=False).index[1:6]  # Excluding 'Area Mean' itself

# Generate box plots for 'Area Mean' vs. correlated features
plt.figure(figsize=(15, 8))
for i, feature in enumerate(correlated_features, 1):
    plt.subplot(2, 3, i)
    sns.boxplot(x=pd.qcut(data[feature], q=4, duplicates='drop'), y=data['Area Mean'])
    plt.xticks(rotation=45)
    plt.title(f"Box Plot: Area Mean vs {feature}")
    plt.xlabel(feature)
    plt.ylabel("Area Mean")

plt.tight_layout()
plt.show()

# %%
# Generate a box plot for 'Area Mean' vs. 'Texture Mean'
plt.figure(figsize=(8, 6))
sns.boxplot(x=pd.qcut(data['Texture Mean'], q=4, duplicates='drop'), y=data['Area Mean'])
plt.xticks(rotation=45)
plt.title("Box Plot: Area Mean vs Texture Mean")
plt.xlabel("Texture Mean (Binned)")
plt.ylabel("Area Mean")
plt.show()

# %%
# Generate a box plot for 'Area Mean' vs. 'Compactness Mean'
plt.figure(figsize=(8, 6))
sns.boxplot(x=pd.qcut(data['Compactness Mean'], q=4, duplicates='drop'), y=data['Area Mean'])
plt.xticks(rotation=45)
plt.title("Box Plot: Area Mean vs Compactness Mean")
plt.xlabel("Compactness Mean (Binned)")
plt.ylabel("Area Mean")
plt.show()

# %% [markdown]
# # 📌Task 4: Apply Linear Regression

# %%
import statsmodels.api as sm
from sklearn.model_selection import train_test_split

# Define target and predictor variables
target = 'Area Mean'
predictors = [col for col in data.columns if col not in ['Area Mean', 'Diagnosis']]

# Split dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(data[predictors], data[target], test_size=0.2, random_state=42)

# Add a constant term for the intercept in the regression model
X_train_const = sm.add_constant(X_train) 

# Fit the model using statsmodels OLS regression
model_sm = sm.OLS(y_train, X_train_const).fit()

# Display model summary
print(model_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              Area Mean   R-squared:                       0.997
# Model:                            OLS   Adj. R-squared:                  0.997
# Method:                 Least Squares   F-statistic:                     5489.
# Date:                Tue, 11 Feb 2025   Prob (F-statistic):               0.00
# Time:                        20:59:03   Log-Likelihood:                -1968.2
# No. Observations:                 455   AIC:                             3996.
# Df Residuals:                     425   BIC:                             4120.
# Df Model:                          29
# Covariance Type:            nonrobust
# ...
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                    -313.5940     35.146     -8.923      0.000    -382.676    -244.512
# ...

# %% [markdown]
# When we first performed linear regression, we used all of the features, now we  will add them one at a time using comments to remove any predictors with p values > 0.05, to determine which combination of predictors is linearly related to our target __Area Mean__.

# %%
# Define target and predictor variables
target = 'Area Mean'
selected_predictors = ['Radius Mean'
                       ,
                       'Perimeter Mean',
                       'Compactness Mean',
                       #'Concavity Mean',
                       #'Fractal Dimension Mean',
                       #'Radius SE',
                       'Texture SE',
                       'Perimeter SE',
                       'Area SE',
                       'Smoothness SE',
                       #'Compactness SE',
                       'Concavity SE',
                       'Concave Points SE',
                       #'Symmetry SE', 
                      # 'Fractal Dimension SE',
                       'Radius Worst',
                       'Texture Worst',
                       'Perimeter Worst', 
                       'Area Worst',
                       #'Smoothness Worst',
                       #'Compactness Worst',
                       #'Concavity Worst',
                       'Concave Points Worst',
                       'Symmetry Worst',
                       'Fractal Dimension Worst'
                      ]  # Adding Concave Points Mean

# Split dataset using selected predictors
X_train_selected, X_test_selected, y_train, y_test = train_test_split(
    data[selected_predictors], data[target], test_size=0.2, random_state=42
)

# Add a constant term for the intercept in the regression model
X_train_const_selected = sm.add_constant(X_train_selected)

# Fit the model using statsmodels OLS regression
model_sm_selected = sm.OLS(y_train, X_train_const_selected).fit()

# Display model summary
print(model_sm_selected.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              Area Mean   R-squared:                       0.997
# Model:                            OLS   Adj. R-squared:                  0.997
# Method:                 Least Squares   F-statistic:                     9653.
# Date:                Tue, 11 Feb 2025   Prob (F-statistic):               0.00
# Time:                        20:59:03   Log-Likelihood:                -1981.8
# No. Observations:                 455   AIC:                             3998.
# Df Residuals:                     438   BIC:                             4068.
# Df Model:                          16
# Covariance Type:            nonrobust
# ...
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                    -294.6513     17.540    -16.798      0.000    -329.125    -260.178
# ...

# %% [markdown]
# # Task 5: Performance Evaluation Metrics

# %%
# Predict on the test set
X_test_const_selected = sm.add_constant(X_test_selected)
y_pred = model_sm_selected.predict(X_test_const_selected)

# Calculate Mean Squared Error (MSE) and Mean Absolute Error (MAE)
mse = np.mean((y_test - y_pred) ** 2)
mae = np.mean(np.abs(y_test - y_pred))

# Calculate R-squared (coefficient of determination)
r2 = model_sm_selected.rsquared

# Display results
print(f"Mean Squared Error (MSE): {mse}")
print(f"Mean Absolute Error (MAE): {mae}")
print(f"R-squared (R²): {r2}")
# Out:
# Mean Squared Error (MSE): 517.0908769551364
# Mean Absolute Error (MAE): 14.366598960299502
# R-squared (R²): 0.9971720828406705

# %% [markdown]
# # Task 6: Residual Analysis

# %%
# Residual analysis
residuals = y_test - y_pred
plt.figure(figsize=(10, 6))
sns.histplot(residuals, bins=30, kde=True)
plt.title("Residual Distribution")
plt.show()

plt.figure(figsize=(10, 6))
plt.scatter(y_pred, residuals)
plt.axhline(y=0, color='r', linestyle='--')
plt.title("Residual Plot")
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.show()

# Report results
report = {
        "Regression Performance": {
        "MSE": mse,
        "MAE": mae,
        "R2": r2
    }
}
print(report)
# Out:
# {'Regression Performance': {'MSE': 517.0908769551364, 'MAE': 14.366598960299502, 'R2': 0.9971720828406705}}

# %%
# Compute correlation matrix
correlation_matrix = data.corr()

# Get the features most correlated with 'Area Mean'
correlated_features = correlation_matrix['Area Mean'].abs().sort_values(ascending=False).index[1:6]  # Excluding 'Area Mean' itself

# Select top 5 independent features for residual analysis
selected_features = correlated_features[:5]

# Generate residual plots for each selected feature
plt.figure(figsize=(15, 10))
for i, feature in enumerate(selected_features, 1):
    plt.subplot(2, 3, i)
    sns.scatterplot(x=X_test[feature], y=residuals)
    plt.axhline(y=0, color='r', linestyle='--')
    plt.title(f"Residual Plot: {feature} vs Residuals")
    plt.xlabel(feature)
    plt.ylabel("Residuals")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 📌 Linear Regression Equation for `Area Mean`
# The equation follows the multiple linear regression format:
#
# $$
# \hat{y} = \beta_0 + \beta_1 X_1 + \beta_2 X_2 + \dots + \beta_n X_n
# $$
#
# Where:
#
# $$
# \hat{y} = \text{Predicted Area Mean}
# $$
#
# $$
# \beta_0 = \text{Intercept (constant term)} (-294.6513)
# $$
#
# $$
# \beta_i = \text{Coefficient for each predictor}
# $$
#
# $$
# X_i = \text{Value of each predictor variable}
# $$
# ---
#
# ## 📊 Final Equation for `Area Mean`
# $$
# \hat{y} = -294.6513 + (80.8648 \cdot X_1) + (5.3169 \cdot X_2) + (-340.3389 \cdot X_3) + (-7.8635 \cdot X_4)
# $$
#
# $$
# + (24.1204 \cdot X_5) + (-0.5289 \cdot X_6) + (2170.4383 \cdot X_7) + (272.0531 \cdot X_8) + (-3484.2513 \cdot X_9)
# $$
#
# $$
# + (-52.8637 \cdot X_{10}) + (0.5279 \cdot X_{11}) + (-3.2426 \cdot X_{12}) + (0.5046 \cdot X_{13}) + (331.5364 \cdot X_{14})
# $$
#
# $$
# + (50.7969 \cdot X_{15})
# $$
#
# ---
#
# ## 📌 Key for Variables
#
# | Symbol | Feature Name |
# |---------|----------------------|
# | $$ X_{1} $$ | `Radius Mean` |
# | $$ X_{2} $$ | `Perimeter Mean` |
# | $$ X_{3} $$ | `Compactness Mean` |
# | $$ X_{4} $$ | `Texture SE` |
# | $$ X_{5} $$ | `Perimeter SE` |
# | $$ X_{6} $$ | `Area SE` |
# | $$ X_{7}$$ | `Smoothness SE` |
# | $$ X_{8} $$ | `Concavity SE` |
# | $$ X_{9} $$ | `Concave Points SE` |
# | $$ X_{10} $$| `Radius Worst` |
# | $$ X_{11} $$| `Texture Worst` |
# | $$ X_{12} $$| `Perimeter Worst` |
# | $$ X_{13} $$ | `Area Worst` |
# | $$ X_{14} $$ | `Concave Points Worst` |
# | $$ X_{15} $$ | `Symmetry Worst` |
# ---
